# %%
import pandas as pd
import numpy as np
import json

csv_paths = ["data/annotations/ZZ_4_2.csv", "data/annotations/ZZ_5.csv"]
for csv_path in csv_paths:
    marker = csv_path.split("/")[-1].split(".")[0]

    df = pd.read_csv(csv_path)
    # modify the column name
    for col in df.columns:
        df = df.rename(columns={col: col.strip().strip("\\n")})

    # replace nan with ""
    df = df.replace(np.nan, "")

    video = None
    video_list = []

    for row in df.iterrows():
        row = row[1]
        if row["视频序号"]:
            if video:
                video_list.append(video)
            video = {}
            video["video_id"] = marker + "_" + str(int(row["视频序号"]))
            video["video_url"] = row["视频_url"]
            video["video_duration"] = row["视频长度（min）"]
            video["video_type"] = row["视频类型"]
            video["qa_list"] = []
        qa = {
            "question": row["问题"],
            "answer": row["答案"],
            "question_type": row["问题类型"],
            "knowledge": row["若涉及通用知识推理，则写出推理步骤（知识点）"],
            "reasoning": row["依据（解题思路）"],
        }
        video["qa_list"].append(qa)

    video_list.append(video)

    print(f"Detected {len(video_list)} videos from {marker}")

    # save the video_list to a json file
    with open(f"data/annotations/{marker}.json", "w") as f:
        json.dump(video_list, f, ensure_ascii=False, indent=4)
# Out:
# Detected 30 videos from ZZ_4_2
# Detected 100 videos from ZZ_5

# %%
import os
import json

processing_config = json.load(open("configs/processing_config.json"))
log_dir = processing_config["log_dir"]
os.makedirs(log_dir, exist_ok=True)

count = 0
annotaions_paths = ["data/annotations/ZZ_4_2.json", "data/annotations/ZZ_5.json"]

for annotaions_path in annotaions_paths:
    marker = annotaions_path.split("/")[-1].split(".")[0]
    with open(annotaions_path, "r") as f:
        data = json.load(f)

    for video in data:
        url = video["video_url"]
        if not url.startswith("https://www.youtube.com/watch?v="):
            count += 1
            with open(
                os.path.join(log_dir, f"annotation_processing_error.log"), "a"
            ) as f:
                f.write(f"Error video url from {marker}: {url}" + "\n")

print(f"Total error video urls: {count}")
# Out:
# Total error video urls: 0

# %%
from utils.chat_api import generate_messages, parallel_get_response
from prompts import prompt_refine_qa_list
from utils.general import validate_and_fix_python_list
import json

annotaions_paths = ["data/annotations/ZZ_4_2.json", "data/annotations/ZZ_5.json"]

for annotaions_path in annotaions_paths:
    marker = annotaions_path.split("/")[-1].split(".")[0]
    with open(annotaions_path, "r") as f:
        data = json.load(f)

    inputs = []

    for video in data:
        qa_list = video["qa_list"]
        qa_list = [
            {"question": qa["question"], "answer": qa["answer"]} for qa in qa_list
        ]
        input = [
            {"type": "text", "content": prompt_refine_qa_list.format(qa_list=qa_list)}
        ]
        inputs.append(input)

    messages = [generate_messages(input) for input in inputs]
    model = "gpt-4o-2024-05-13"

    responses = parallel_get_response(model, messages)[0]

    for video, response in zip(data, responses):
        refined_qa_list = validate_and_fix_python_list(response)
        for qa, refined_qa in zip(video["qa_list"], refined_qa_list):
            print(f"Original question: {qa['question']}")
            print(f"Refined question: {refined_qa['question']}")
            print(f"Original answer: {qa['answer']}")
            print(f"Refined answer: {refined_qa['answer']}")
            qa["question"] = refined_qa["question"]
            qa["answer"] = refined_qa["answer"]
            print("-" * 100)
        print("=" * 100)

    with open(f"data/annotations/{marker}_refined.json", "w") as f:
        json.dump(data, f, ensure_ascii=False, indent=4)
# Out:
# Original question: Which one has better remote control car operation skills, Hal or Benji?
# Refined question: Who has better remote control car operation skills, Hal or Benji?
# Original answer: Hal.
# Refined answer: Hal.
# ----------------------------------------------------------------------------------------------------
# Original question: Is Hal proficient in assembling remote-controlled cars?
# Refined question: Is Hal proficient in assembling remote-controlled cars?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# Original question: What is the marked price of the car that Benji chose?
# Refined question: What is the marked price of the car that Benji chose?
# Original answer: Twenty-nine dollars and ninety-nine cents.
# Refined answer: Twenty-nine dollars and ninety-nine cents.
# ----------------------------------------------------------------------------------------------------
# Original question: Is RIDEMAKERZ a one-stop service or a multi-stop service?
# Refined question: Is RIDEMAKERZ a one-stop service or a multi-stop service?
# Original answer: RIDEMAKERZ is a one-stop service.
# Refined answer: RIDEMAKERZ is a one-stop service.
# ----------------------------------------------------------------------------------------------------
# Original question: Is it difficult to assemble a remote control car alone at RIDEMAKERZ?
# Refined question: Is it difficult to assemble a remote control car alone at RIDEMAKERZ?
# Original answer: No.
# Refined answer: No.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question:  Was Matthew's introduction meticulous or perfunctory?
# Refined question: Was Matthew's introduction meticulous or perfunctory?
# Original answer: Careful.
# Refined answer: Meticulous.
# ----------------------------------------------------------------------------------------------------
# Original question: Is this Jaeger-LeCoultre a newly established brand?
# Refined question: Is Jaeger-LeCoultre a newly established brand?
# Original answer: No.
# Refined answer: No.
# ----------------------------------------------------------------------------------------------------
# Original question: After Matthew introduced the history of Jaeger-LeCoultre, what did he start to introduce to Teddy next?
# Refined question: After Matthew introduced the history of Jaeger-LeCoultre, what did he introduce to Teddy next?
# Original answer: Mechanical parts.
# Refined answer: Mechanical parts.
# ----------------------------------------------------------------------------------------------------
# Original question: Which word is more suitable for Teddy's interviews, professional or amateur?
# Refined question: Which word is more suitable for Teddy's interviews, professional or amateur?
# Original answer: Professional.
# Refined answer: Professional.
# ----------------------------------------------------------------------------------------------------
# Original question: Is the manufacturing of Jaeger-LeCoultre meticulous and rigorous?
# Refined question: Is the manufacturing of Jaeger-LeCoultre meticulous and rigorous?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: Which word is more suitable to describe Kirsi's introduction, “enthusiastic” or “indifferent”?
# Refined question: Which word is more suitable to describe Kirsi's introduction, 'enthusiastic' or 'indifferent'?
# Original answer: Enthusiastic.
# Refined answer: Enthusiastic.
# ----------------------------------------------------------------------------------------------------
# Original question: Should the panels of a car be aligned before painting?
# Refined question: Should the panels of a car be aligned before painting?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# Original question: After Steven visited the lounge, where did he go next?
# Refined question: After Steven visited the lounge, where did he go next?
# Original answer: Production floor.
# Refined answer: The production floor.
# ----------------------------------------------------------------------------------------------------
# Original question: Is Cleo interested in racing cars?
# Refined question: Is Cleo interested in racing cars?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# Original question: To reduce the weight, what materials does Koenigsegg Factory use for the Jesko?
# Refined question: To reduce the weight, what materials does the Koenigsegg Factory use for the Jesko?
# Original answer: Carbon Fiber.
# Refined answer: Carbon fiber.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: Is Tara an interviewer with strong affinity or a cold one?
# Refined question: Is Tara an interviewer with a strong affinity or a cold demeanor?
# Original answer: She is a strong affinity interviewr.
# Refined answer: She is an interviewer with a strong affinity.
# ----------------------------------------------------------------------------------------------------
# Original question: How many days a week does Grand Design support factory tours?
# Refined question: How many days a week does Grand Design offer factory tours?
# Original answer: Four days.
# Refined answer: Four days.
# ----------------------------------------------------------------------------------------------------
# Original question: Which word is more suitable for Austin's introduction, "professional" or "amateur"?
# Refined question: Which word is more suitable for Austin's introduction, 'professional' or 'amateur'?
# Original answer: Professional
# Refined answer: Professional.
# ----------------------------------------------------------------------------------------------------
# Original question: Compared with the traditional way of building houses from the outside in, how is a recreational vehicle (RV) built?
# Refined question: Compared to the traditional method of building houses from the outside in, how is a recreational vehicle (RV) constructed?
# Original answer: From the inside out.
# Refined answer: From the inside out.
# ----------------------------------------------------------------------------------------------------
# Original question: After introducing the slide-out box of the RV, which part of the RV was introduced next?
# Refined question: After introducing the slide-out box of the RV, which part of the RV was introduced next?
# Original answer: Roof.
# Refined answer: The roof.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: Is Cleo interested in racing cars?
# Refined question: Is Cleo interested in racing cars?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# Original question: What is used to reduce the driving resistance increased by the rear wing of an Formula 1 car?
# Refined question: What is used to reduce the driving resistance increased by the rear wing of a Formula 1 car?
# Original answer: DRS（Drag Reduction System）.
# Refined answer: DRS (Drag Reduction System).
# ----------------------------------------------------------------------------------------------------
# Original question: Which word is more suitable to describe Jack's explanation, "understandable" or "obscure"?
# Refined question: Which word is more suitable to describe Jack's explanation, 'understandable' or 'obscure'?
# Original answer: Understandable.
# Refined answer: Understandable.
# ----------------------------------------------------------------------------------------------------
# Original question: After visiting the warehouse, through whom did Cleo learn about the design concept of the winning racing car?
# Refined question: After visiting the warehouse, through whom did Cleo learn about the design concept of the winning racing car?
# Original answer: Jake.
# Refined answer: Jake.
# ----------------------------------------------------------------------------------------------------
# Original question: From the perspective of aerodynamics, what factors are related to the extremely fast cornering speed of a racing car?
# Refined question: From the perspective of aerodynamics, what factors are related to the extremely fast cornering speed of a racing car?
# Original answer: Downforce.
# Refined answer: Downforce.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: Where did Aragorn be born?
# Refined question: Where was Aragorn born?
# Original answer: British Virgin Island.
# Refined answer: British Virgin Islands.
# ----------------------------------------------------------------------------------------------------
# Original question: Is the terrain of British Virgin Island suitable for farmland reclamation?
# Refined question: Is the terrain of the British Virgin Islands suitable for farmland reclamation?
# Original answer: No.
# Refined answer: No.
# ----------------------------------------------------------------------------------------------------
# Original question: What plants are used to enrich the soil in British Virgin Island？
# Refined question: What plants are used to enrich the soil in the British Virgin Islands?
# Original answer: Sun hemp.
# Refined answer: Sunn hemp.
# ----------------------------------------------------------------------------------------------------
# Original question:  How to deal with the rocks encountered when opening terraces？
# Refined question: How should the rocks encountered when opening terraces be dealt with?
# Original answer: To build terraces.
# Refined answer: By building terraces.
# ----------------------------------------------------------------------------------------------------
# Original question: Is Aragorn smart or dull？
# Refined question: Is Aragorn intelligent or dull?
# Original answer: He is smart.
# Refined answer: He is intelligent.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: What is Luck Brett‘s job？
# Refined question: What is Luke Brett's job?
# Original answer: Stevedores and transporters of chicken coops.
# Refined answer: Stevedore and transporter of chicken coops.
# ----------------------------------------------------------------------------------------------------
# Original question: How many species of wild animals did the author capture with their trail cameras?
# Refined question: How many species of wild animals did the author capture with their trail cameras?
# Original answer: Five.
# Refined answer: Five.
# ----------------------------------------------------------------------------------------------------
# Original question: Are there wild monkeys in Florida？
# Refined question: Are there wild monkeys in Florida?
# Original answer: No.
# Refined answer: No.
# ----------------------------------------------------------------------------------------------------
# Original question: What is the correct way to pick up a chicken？
# Refined question: What is the correct way to pick up a chicken?
# Original answer: Put your hands underneath their breast.
# Refined answer: Place your hands underneath its breast.
# ----------------------------------------------------------------------------------------------------
# Original question: Is the couple willing to listen to opinions or be arbitrary
# Refined question: Is the couple willing to listen to opinions or be arbitrary?
# Original answer: They are willing to listen to opinions.
# Refined answer: They are willing to listen to opinions.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: How many pounds of feed does Scott Brown have?
# Refined question: How many pounds of feed does Scott Brown have?
# Original answer: About 88,000 pounds.
# Refined answer: About 88,000 pounds.
# ----------------------------------------------------------------------------------------------------
# Original question: Among Easter egrets, Rhode Island red chickens, quails, who are least affected by the environment？
# Refined question: Among Easter egrets, Rhode Island red chickens, and quails, which are least affected by the environment?
# Original answer: Quails.
# Refined answer: Quails.
# ----------------------------------------------------------------------------------------------------
# Original question: What is Scott Brown's favorite vegetable？
# Refined question: What is Scott Brown's favorite vegetable?
# Original answer: Tomato.
# Refined answer: Tomato.
# ----------------------------------------------------------------------------------------------------
# Original question: How many vitamins can be supplemented by bitter melon?
# Refined question: How many vitamins can be supplemented by bitter melon?
# Original answer: Two.
# Refined answer: Two.
# ----------------------------------------------------------------------------------------------------
# Original question: Which aspect of health in daily life does the author pay more attention to?
# Refined question: Which aspect of health in daily life does the author pay more attention to?
# Original answer: Food health.
# Refined answer: Food health.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: What are the toxic compounds in cherry pits?
# Refined question: What are the toxic compounds in cherry pits?
# Original answer: Cyanogenic glycosides.
# Refined answer: Cyanogenic glycosides.
# ----------------------------------------------------------------------------------------------------
# Original question: What is the atmosphere of the interaction between Patrick and Nick, is it relaxed or tense?
# Refined question: Is the atmosphere of the interaction between Patrick and Nick relaxed or tense?
# Original answer: Relaxed.
# Refined answer: Relaxed.
# ----------------------------------------------------------------------------------------------------
# Original question: After evaluating the cherry pitter, what did Nick and Patrick evaluate next?
# Refined question: After evaluating the cherry pitter, what did Nick and Patrick evaluate next?
# Original answer: Egg beater.
# Refined answer: An egg beater.
# ----------------------------------------------------------------------------------------------------
# Original question: Which word can better describe Patrick's personality, “humorous” or “dull”?
# Refined question: Which word better describes Patrick's personality, 'humorous' or 'dull'?
# Original answer: Humorous.
# Refined answer: Humorous.
# ----------------------------------------------------------------------------------------------------
# Original question: Does “Slap Chop” need to be plugged in for use?
# Refined question: Does the 'Slap Chop' need to be plugged in for use?
# Original answer: No.
# Refined answer: No.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: Is Joe more proficient or less proficient in learning knowledge in the field of engineering?
# Refined question: Is Joe more proficient or less proficient in learning knowledge in the field of engineering?
# Original answer: He is more proficient.
# Refined answer: He is more proficient.
# ----------------------------------------------------------------------------------------------------
# Original question: Is the small town of GLY in California a place where many world records have been set?
# Refined question: Is the small town of GLY in California a place where many world records have been set?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# Original question: Where did the eggs that Mark used in his experiment come from?
# Refined question: Where did the eggs that Mark used in his experiment come from?
# Original answer: The eggs were laid by Gidly.
# Refined answer: The eggs were laid by Gidly.
# ----------------------------------------------------------------------------------------------------
# Original question: Did Adam Steltner have a positive or negative attitude towards Mark's initial experiment of dropping an egg from a high place?
# Refined question: Did Adam Steltner have a positive or negative attitude towards Mark's initial experiment of dropping an egg from a high place?
# Original answer: He had a negative attitude.
# Refined answer: He had a negative attitude.
# ----------------------------------------------------------------------------------------------------
# Original question: Is the small town of Gridley in California quite suitable for agricultural cultivation?
# Refined question: Is the small town of Gridley in California quite suitable for agricultural cultivation?
# Original answer: yes
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: How many places did Brent and his friends explore?
# Refined question: How many places did Brent and his friends explore?
# Original answer: Five
# Refined answer: Five
# ----------------------------------------------------------------------------------------------------
# Original question: Is Brent an adventurous person?
# Refined question: Is Brent an adventurous person?
# Original answer: Yes
# Refined answer: Yes
# ----------------------------------------------------------------------------------------------------
# Original question: Is Brent a person who likes to play pranks?
# Refined question: Does Brent enjoy playing pranks?
# Original answer: Yes
# Refined answer: Yes
# ----------------------------------------------------------------------------------------------------
# Original question: Where is SUNKEN AIRPLANE located?
# Refined question: Where is the sunken airplane located?
# Original answer: Bahamas
# Refined answer: Bahamas
# ----------------------------------------------------------------------------------------------------
# Original question: Where is ABANDONED PLANE CRASH located?
# Refined question: Where is the abandoned plane crash located?
# Original answer: Oregon
# Refined answer: Oregon
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: What is the relationship between the two people in the video?
# Refined question: What is the relationship between the two people in the video?
# Original answer: Couple
# Refined answer: They are a couple.
# ----------------------------------------------------------------------------------------------------
# Original question: Does Mr. H enjoy the planting process?
# Refined question: Does Mr. H enjoy the planting process?
# Original answer: Yes
# Refined answer: Yes, he does.
# ----------------------------------------------------------------------------------------------------
# Original question: How many trays of potatoes did the blogger prepare for planting?
# Refined question: How many trays of potatoes did the blogger prepare for planting?
# Original answer: Seven plates
# Refined answer: Seven trays.
# ----------------------------------------------------------------------------------------------------
# Original question: What trace elements will potatoes lack if bone meal is not applied to potatoes?
# Refined question: What trace elements will potatoes lack if bone meal is not applied?
# Original answer: Phosphorus
# Refined answer: Phosphorus.
# ----------------------------------------------------------------------------------------------------
# Original question: Do garden lime and composted chicken manure have the same pH?
# Refined question: Do garden lime and composted chicken manure have the same pH?
# Original answer: No
# Refined answer: No, they do not.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: Does this female reporter love her job?
# Refined question: Does the female reporter enjoy her job?
# Original answer: Yes
# Refined answer: Yes
# ----------------------------------------------------------------------------------------------------
# Original question: Does the first person the reporter interview have a positive or negative attitude toward life?
# Refined question: Does the first person interviewed by the reporter have a positive or negative attitude towards life?
# Original answer: Negative
# Refined answer: Negative
# ----------------------------------------------------------------------------------------------------
# Original question: How many people did the female reporter interview?
# Refined question: How many people did the female reporter interview?
# Original answer: Three people
# Refined answer: Three
# ----------------------------------------------------------------------------------------------------
# Original question: Is Ramat Park a clean and tidy place?
# Refined question: Is Ramat Park a clean and tidy place?
# Original answer: No
# Refined answer: No
# ----------------------------------------------------------------------------------------------------
# Original question: Is the price level in the Ramat Park area high or low?
# Refined question: Is the price level in the Ramat Park area high or low?
# Original answer: High
# Refined answer: High
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: Is Bondi a responsible vet ?
# Refined question: Is Bondi a responsible veterinarian?
# Original answer: Yes, he is.
# Refined answer: Yes, he is.
# ----------------------------------------------------------------------------------------------------
# Original question: Do Nicole and Mark really care about their dog Kiko or not ?
# Refined question: Do Nicole and Mark genuinely care about their dog Kiko?
# Original answer: They really care about Kiko.
# Refined answer: They genuinely care about Kiko.
# ----------------------------------------------------------------------------------------------------
# Original question: Can gastroenteritis in puppies lead to low protein?
# Refined question: Can gastroenteritis in puppies lead to low protein levels?
# Original answer: Yes, it can.
# Refined answer: Yes, it can.
# ----------------------------------------------------------------------------------------------------
# Original question: What is always added to medicine to help alleviate the pain caused by arthritis in cats?
# Refined question: What is always added to medicine to help alleviate the pain caused by arthritis in cats?
# Original answer: Green-lipped mussel.
# Refined answer: Green-lipped mussel.
# ----------------------------------------------------------------------------------------------------
# Original question: How many pets appeared in the video in total ?
# Refined question: How many pets appeared in the video in total?
# Original answer: 4.
# Refined answer: Four.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: Is the MMA electric drive system efficient or inefficient?
# Refined question: Is the MMA electric drive system efficient or inefficient?
# Original answer: Efficient.
# Refined answer: Efficient.
# ----------------------------------------------------------------------------------------------------
# Original question: Which category of electronic product does Justine like the best.
# Refined question: Which category of electronic product does Justine like the best?
# Original answer: The camera.
# Refined answer: The camera.
# ----------------------------------------------------------------------------------------------------
# Original question: Is Brian a humorous or serious host ?
# Refined question: Is Brian a humorous or serious host?
# Original answer: He is humorous.
# Refined answer: He is humorous.
# ----------------------------------------------------------------------------------------------------
# Original question: Is the Pebble Flow an innovative travel trailer?
# Refined question: Is the Pebble Flow an innovative travel trailer?
# Original answer: Yes, it is.
# Refined answer: Yes, it is.
# ----------------------------------------------------------------------------------------------------
# Original question: Which brand was introduced after the sumsung ?
# Refined question: Which brand was introduced after Samsung?
# Original answer: Insta.
# Refined answer: Insta.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: Is the stable atmosphere and high transparency of the Antarctic one of the reasons why explorers go to the Antarctic?
# Refined question: Is the stable atmosphere and high transparency of Antarctica one of the reasons why explorers go there?
# Original answer: yes
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# Original question: What is the lowest temperature that Antarctica can reach?
# Refined question: What is the lowest temperature that Antarctica can reach?
# Original answer: -80
# Refined answer: -80 degrees Celsius.
# ----------------------------------------------------------------------------------------------------
# Original question: Does Jonathan Walton have a stronger obsession with Antarctica or a deeper sense of reluctance towards it?
# Refined question: Does Jonathan Walton have a stronger obsession with Antarctica or a deeper sense of reluctance towards it?
# Original answer: He has a deep obsession with Antarctica.
# Refined answer: He has a deep obsession with Antarctica.
# ----------------------------------------------------------------------------------------------------
# Original question: What are the common uses of CFC?
# Refined question: What are the common uses of CFCs?
# Original answer: fridge, aerosol and plastic.
# Refined answer: Refrigerators, aerosols, and plastics.
# ----------------------------------------------------------------------------------------------------
# Original question: When Jonathan Walton came to the Stunnington Islands again, did he have a very complicated feeling?
# Refined question: When Jonathan Walton returned to the Stunnington Islands, did he have very complicated feelings?
# Original answer: yes
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: What's Mek's job?
# Refined question: What is Mek's job?
# Original answer: Coachman
# Refined answer: Coachman
# ----------------------------------------------------------------------------------------------------
# Original question: What is the main mode of transportation for Amish people?
# Refined question: What is the main mode of transportation for Amish people?
# Original answer: Buggy
# Refined answer: Buggy
# ----------------------------------------------------------------------------------------------------
# Original question: Does Lizzy know how to use a sewing machine?
# Refined question: Does Lizzy know how to use a sewing machine?
# Original answer: Yes,she does
# Refined answer: Yes, she does
# ----------------------------------------------------------------------------------------------------
# Original question: How Amish people preserve food?
# Refined question: How do Amish people preserve food?
# Original answer: Use a jar to seal.
# Refined answer: They use jars to seal it.
# ----------------------------------------------------------------------------------------------------
# Original question: What sourceof water do the Amish use to wash clothes?
# Refined question: What source of water do the Amish use to wash clothes?
# Original answer: Rainwater
# Refined answer: Rainwater
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: What's the author's favorite game?
# Refined question: What is the author's favorite game?
# Original answer: Star Wars
# Refined answer: Star Wars.
# ----------------------------------------------------------------------------------------------------
# Original question: For which customers is the Elgato Prompter designed?
# Refined question: For which customers is the Elgato Prompter designed?
# Original answer: Content creators, streamers, and professionals.
# Refined answer: Content creators, streamers, and professionals.
# ----------------------------------------------------------------------------------------------------
# Original question: Is Emy lively in personality?
# Refined question: Is Emy lively in personality?
# Original answer: Yes
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# Original question: Is the Gamescom exclusively focused on indie games?
# Refined question: Is Gamescom exclusively focused on indie games?
# Original answer: No
# Refined answer: No.
# ----------------------------------------------------------------------------------------------------
# Original question: After visiting the Assassin's Creed exhibition area, which exhibition area did the author go to?
# Refined question: After visiting the Assassin's Creed exhibition area, which exhibition area did the author go to?
# Original answer: Fifa exhibition area
# Refined answer: The FIFA exhibition area.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: Where will the refueling-receiving aircraft be positioned relative to the KC-46 during mid-air refueling?
# Refined question: Where will the refueling-receiving aircraft be positioned relative to the KC-46 during mid-air refueling?
# Original answer: Lower rear part.
# Refined answer: In the lower rear part.
# ----------------------------------------------------------------------------------------------------
# Original question: Is the KC-46 both a refueling tanker and a receiving aircraft?
# Refined question: Is the KC-46 both a refueling tanker and a receiving aircraft?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# Original question: What is the relationship between Nat and Ollie Sladenko?
# Refined question: What is the relationship between Nat and Ollie Sladenko?
# Original answer: They are colleagues.
# Refined answer: They are colleagues.
# ----------------------------------------------------------------------------------------------------
# Original question: Are Nat and Jasmine Miller's jobs the same?
# Refined question: Are Nat and Jasmine Miller's jobs the same?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# Original question: What layout does the B-2 bomber adopt?
# Refined question: What layout does the B-2 bomber adopt?
# Original answer: Flying - wing layout.
# Refined answer: Flying-wing layout.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: What is David's identity?
# Refined question: What is David's identity?
# Original answer: One of the owner of Sunset Market Gardens.
# Refined answer: One of the owners of Sunset Market Gardens.
# ----------------------------------------------------------------------------------------------------
# Original question: What kind of weather will most likely affect the farms in Reedsville North Carolina after May?
# Refined question: What kind of weather will most likely affect the farms in Reedsville, North Carolina after May?
# Original answer: Wind.
# Refined answer: Wind.
# ----------------------------------------------------------------------------------------------------
# Original question: Are potatoes expensive or cheap in Reedsville North Carolina?
# Refined question: Are potatoes expensive or cheap in Reedsville, North Carolina?
# Original answer: Expensive.
# Refined answer: Expensive.
# ----------------------------------------------------------------------------------------------------
# Original question: Is it long or short to grow potatoes in the Sunset Market Garden?
# Refined question: Is it a long or short process to grow potatoes in the Sunset Market Garden?
# Original answer: Short.
# Refined answer: Short.
# ----------------------------------------------------------------------------------------------------
# Original question: Does David have a lot of experience or a lack of experience in agricultural cultivation?
# Refined question: Does David have a lot of experience or a lack of experience in agricultural cultivation?
# Original answer: He has a lot of experience.
# Refined answer: He has a lot of experience.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: Does Dallin pay attention to his body management in daily life?
# Refined question: Does Dallin pay attention to his body management in daily life?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# Original question: Has the Paia Fish Market been in business for more than five years or less than five years?
# Refined question: Has the Paia Fish Market been in business for more than five years or less than five years?
# Original answer: More than five years.
# Refined answer: More than five years.
# ----------------------------------------------------------------------------------------------------
# Original question: During the surfing process, does Story like it more or be more afraid of it?
# Refined question: During the surfing process, does Story enjoy it more or fear it more?
# Original answer: She likes it more.
# Refined answer: She enjoys it more.
# ----------------------------------------------------------------------------------------------------
# Original question: In addition to surfing, what other sports and competitive hobbies does Dallin have?
# Refined question: In addition to surfing, what other sports and competitive hobbies does Dallin have?
# Original answer: Car racing.
# Refined answer: Car racing.
# ----------------------------------------------------------------------------------------------------
# Original question: Is there a beach on Maui Island suitable for beginners to learn surfing?
# Refined question: Is there a beach on Maui Island suitable for beginners to learn surfing?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: Is dining in available at Arome?
# Refined question: Is dining in available at Arome?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# Original question: What role does Luke play in the activity of visiting the best bakeries in London?
# Refined question: What role does Luke play in the activity of visiting the best bakeries in London?
# Original answer: The photographer.
# Refined answer: He is the photographer.
# ----------------------------------------------------------------------------------------------------
# Original question: Does Josh like the egg tart or the croissant from Arome better?
# Refined question: Does Josh prefer the egg tart or the croissant from Arome?
# Original answer: The egg tart.
# Refined answer: He prefers the egg tart.
# ----------------------------------------------------------------------------------------------------
# Original question: What is Josh's attitude towards savory pastries?
# Refined question: What is Josh's attitude towards savory pastries?
# Original answer: He likes savory pastries.
# Refined answer: He likes savory pastries.
# ----------------------------------------------------------------------------------------------------
# Original question: Are the flavors of the New Orleans beignette at Fortitude Bakehouse fixed every day?
# Refined question: Are the flavors of the New Orleans beignet at Fortitude Bakehouse fixed every day?
# Original answer: No.
# Refined answer: No.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: Which neighborhood in Manhattan, New York, has the most expensive rent?
# Refined question: Which neighborhood in Manhattan, New York, has the most expensive rent?
# Original answer: Soho.
# Refined answer: Soho.
# ----------------------------------------------------------------------------------------------------
# Original question: Is Tejas a native of New York?
# Refined question: Is Tejas a native of New York?
# Original answer: No.
# Refined answer: No.
# ----------------------------------------------------------------------------------------------------
# Original question: Which city has a higher cost of living, Chicago or Austin?
# Refined question: Which city has a higher cost of living, Chicago or Austin?
# Original answer: Chicago.
# Refined answer: Chicago.
# ----------------------------------------------------------------------------------------------------
# Original question: Which does Shervin think is more important when renting a house, quality or location?
# Refined question: What does Shervin consider more important when renting a house, quality or location?
# Original answer: Location.
# Refined answer: Location.
# ----------------------------------------------------------------------------------------------------
# Original question: In the consumer basket experiment, which food in New York is closest to the market average price?
# Refined question: In the consumer basket experiment, which food in New York is closest to the market average price?
# Original answer: Whole milk.
# Refined answer: Whole milk.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: What kind of food did the airline distribute to Jeel during the flight to Kasani?
# Refined question: What kind of food did the airline distribute to Jeel during the flight to Kasani?
# Original answer: Dried beef.
# Refined answer: Dried beef.
# ----------------------------------------------------------------------------------------------------
# Original question: Is Ray satisfied with the construction of basic living facilities in Botswana?
# Refined question: Is Ray satisfied with the construction of basic living facilities in Botswana?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# Original question: What is the most classic traditional dish in Gaborone?
# Refined question: What is the most classic traditional dish in Gaborone?
# Original answer: Seswaa.
# Refined answer: Seswaa.
# ----------------------------------------------------------------------------------------------------
# Original question: Was the University of Botswana established with the funding from the local government?
# Refined question: Was the University of Botswana established with funding from the local government?
# Original answer: No.
# Refined answer: No.
# ----------------------------------------------------------------------------------------------------
# Original question: What is Jeel's overall attitude towards Botswana?
# Refined question: What is Jeel's overall attitude towards Botswana?
# Original answer: He loves and admires it.
# Refined answer: He loves and admires it.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: Who has a higher official position, Peterson or St. Laurent?
# Refined question: Who holds a higher official position, Peterson or St. Laurent?
# Original answer: Peterson.
# Refined answer: Peterson.
# ----------------------------------------------------------------------------------------------------
# Original question: Who has better physical fitness, Austen or Galdones?
# Refined question: Who has better physical fitness, Austen or Galdones?
# Original answer: Austen.
# Refined answer: Austen.
# ----------------------------------------------------------------------------------------------------
# Original question: What will be used to relieve fatigue after completing the training in the US Army Special Forces?
# Refined question: What will be used to relieve fatigue after completing the training in the US Army Special Forces?
# Original answer: Ice water.
# Refined answer: Ice water.
# ----------------------------------------------------------------------------------------------------
# Original question: What ways will the instructors use to address the new recruits before they join the US Army Special Forces?
# Refined question: How will the instructors address the new recruits before they join the US Army Special Forces?
# Original answer: Use the serial numbers to replace their names.
# Refined answer: They will use serial numbers instead of names.
# ----------------------------------------------------------------------------------------------------
# Original question: Before starting the PT TEST, who chose a sleeping berth closer to the door, Austen or Galdones?
# Refined question: Before starting the PT test, who chose a sleeping berth closer to the door, Austen or Galdones?
# Original answer: Galdones.
# Refined answer: Galdones.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: How to blanch broccoli evenly?
# Refined question: How can broccoli be blanched evenly?
# Original answer: Cut the broccoli into small florets of uniform size.
# Refined answer: Cut the broccoli into small florets of uniform size.
# ----------------------------------------------------------------------------------------------------
# Original question: Is Ann Cromley meticulous or careless?
# Refined question: Is Ann Cromley meticulous or careless?
# Original answer: meticulous
# Refined answer: Meticulous.
# ----------------------------------------------------------------------------------------------------
# Original question: How to make the citrus butter sauce brighter?
# Refined question: How can the citrus butter sauce be made brighter?
# Original answer: Add a little bit of wine.
# Refined answer: Add a little bit of wine.
# ----------------------------------------------------------------------------------------------------
# Original question: Does Alice Waters have leadership skills?
# Refined question: Does Alice Waters possess leadership skills?
# Original answer: Yes
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# Original question: What kind of food did Ann Cromley start preparing after 11:00?
# Refined question: What type of food did Ann Cromley start preparing after 11:00?
# Original answer: Citrus beurre blanc
# Refined answer: Citrus beurre blanc.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: What industrial chemicals can Dr. KUNG'U's rice husk conversion technology produce?
# Refined question: What industrial chemicals can Dr. Kung'u's rice husk conversion technology produce?
# Original answer: Sodium silicate solution
# Refined answer: Sodium silicate solution.
# ----------------------------------------------------------------------------------------------------
# Original question: Is MALKIZELA KAMATHI interested in agriculture or not?
# Refined question: Is Malkizela Kamathi interested in agriculture?
# Original answer:  MALKIZELA KAMATHI interested in agriculture
# Refined answer: Malkizela Kamathi is interested in agriculture.
# ----------------------------------------------------------------------------------------------------
# Original question: Does Kenya grow rice?
# Refined question: Does Kenya grow rice?
# Original answer: Yes
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# Original question: How many booths were interviewed in the video in total?
# Refined question: How many booths were interviewed in the video in total?
# Original answer: Five
# Refined answer: Five.
# ----------------------------------------------------------------------------------------------------
# Original question: Is KELVIN OMBATI creative?
# Refined question: Is Kelvin Ombati creative?
# Original answer: Yes
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: Who opened the effervescent apple wine?
# Refined question: Who opened the effervescent apple wine?
# Original answer: Matt
# Refined answer: Matt
# ----------------------------------------------------------------------------------------------------
# Original question: What team is Buffalo Bills?
# Refined question: What team are the Buffalo Bills?
# Original answer: Rugby football
# Refined answer: A rugby football team.
# ----------------------------------------------------------------------------------------------------
# Original question: Is Chris good at remembering things?
# Refined question: Is Chris good at remembering things?
# Original answer: No
# Refined answer: No.
# ----------------------------------------------------------------------------------------------------
# Original question: Who like farm vanilla cupcake goldfish?
# Refined question: Who likes farm vanilla cupcake goldfish?
# Original answer: Nick
# Refined answer: Nick.
# ...
# Refined question: Is Gerber a responsible person or a perfunctory one?
# Original answer: responsible
# Refined answer: Responsible.
# ----------------------------------------------------------------------------------------------------
# Original question: Is Mia professional or amateur in the field of health?
# Refined question: Is Mia professional or amateur in the field of health?
# Original answer: She is professional in the field of health.
# Refined answer: She is professional in the field of health.
# ----------------------------------------------------------------------------------------------------
# Original question: What color is the outer packaging of the first yogurt tested by Mia？
# Refined question: What color is the outer packaging of the first yogurt tested by Mia?
# Original answer: white
# Refined answer: White.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: Is Dong satisfied with his current life?
# Refined question: Is Dong satisfied with his current life?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# Original question: How many women were interviewed in this session?
# Refined question: How many women were interviewed in this session?
# Original answer: one
# Refined answer: One.
# ----------------------------------------------------------------------------------------------------
# Original question: Are Europeans accustomed to focusing on a single career or engaging in side jobs？
# Refined question: Are Europeans accustomed to focusing on a single career or engaging in side jobs?
# Original answer: Engaging in side jobs.
# Refined answer: Engaging in side jobs.
# ----------------------------------------------------------------------------------------------------
# Original question: Does Django always work on holidays?
# Refined question: Does Django always work on holidays?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# Original question: Has the demand for workers in Asian countries exceeded supply by 2023?
# Refined question: Has the demand for workers in Asian countries exceeded supply by 2023?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: How many techniques did Rob introduce about Litefeet in this video?
# Refined question: How many techniques did Rob introduce regarding Litefeet in this video?
# Original answer: Eight
# Refined answer: Eight
# ----------------------------------------------------------------------------------------------------
# Original question: Is Tango a confident and funny guy?
# Refined question: Is Tango a confident and humorous individual?
# Original answer: Yes
# Refined answer: Yes
# ----------------------------------------------------------------------------------------------------
# Original question: What kind of dance is introduced after ballet in this video?
# Refined question: What type of dance is introduced after ballet in this video?
# Original answer: Waving
# Refined answer: Waving
# ----------------------------------------------------------------------------------------------------
# Original question: Does jaja only have tattoos on her left arm?
# Refined question: Does Jaja have tattoos only on her left arm?
# Original answer: No
# Refined answer: No
# ----------------------------------------------------------------------------------------------------
# Original question: Do Indians like to dance barefoot?
# Refined question: Do Indians prefer to dance barefoot?
# Original answer: Yes
# Refined answer: Yes
# ----------------------------------------------------------------------------------------------------
# Original question: Do the LGBTQ community prefer dances that involve more arm movements?
# Refined question: Does the LGBTQ community prefer dances that involve more arm movements?
# Original answer: Yes
# Refined answer: Yes
# ----------------------------------------------------------------------------------------------------
# Original question: When was the first hip hop party held?
# Refined question: When was the first hip-hop party held?
# Original answer: August 11, 1973
# Refined answer: August 11, 1973
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: What is NC°?
# Refined question: What is NC°?
# Original answer: It is a software for monitoring body temperature.
# Refined answer: It is a software for monitoring body temperature.
# ----------------------------------------------------------------------------------------------------
# Original question: Does Keltie care about the quality of her sleep?
# Refined question: Does Keltie care about the quality of her sleep?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# Original question: How does the weight of Garmin compare to Apple Watch?
# Refined question: How does the weight of the Garmin compare to the Apple Watch?
# Original answer: Garmin is lighter than Apple Watch.
# Refined answer: The Garmin is lighter than the Apple Watch.
# ----------------------------------------------------------------------------------------------------
# Original question: When was Keltie born?
# Refined question: When was Keltie born?
# Original answer: 1990s.
# Refined answer: In the 1990s.
# ----------------------------------------------------------------------------------------------------
# Original question: Can Keltie play golf?
# Refined question: Can Keltie play golf?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: How many people did Will interview at the gym?
# Refined question: How many people did Will interview at the gym?
# Original answer: Five.
# Refined answer: Five.
# ----------------------------------------------------------------------------------------------------
# Original question: How many years has Pathmark in Camden been bankrupt by 2025?
# Refined question: How many years will Pathmark in Camden have been bankrupt by 2025?
# Original answer: 12 years.
# Refined answer: 12 years.
# ----------------------------------------------------------------------------------------------------
# Original question: Does Tennyson attach great importance to fitness？
# Refined question: Does Tennyson attach great importance to fitness?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# Original question: Does Will exercise regularly?
# Refined question: Does Will exercise regularly?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# Original question: Which supermarket in Camden can you buy fresh meat from?
# Refined question: Which supermarket in Camden can you buy fresh meat from?
# Original answer: Save a lot.
# Refined answer: Save-A-Lot.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: How to release Spoon Buddy?
# Refined question: How do you release Spoon Buddy?
# Original answer: Pull the ridge on the bottom suction cup.
# Refined answer: Pull the ridge on the bottom suction cup.
# ----------------------------------------------------------------------------------------------------
# Original question: How did Frankin get to the convenience store?
# Refined question: How did Frankin get to the convenience store?
# Original answer: By driving.
# Refined answer: By driving.
# ----------------------------------------------------------------------------------------------------
# Original question: What size can does Beersy only come in?
# Refined question: What size can does Beersy come in?
# Original answer: 12 oz.
# Refined answer: 12 oz.
# ----------------------------------------------------------------------------------------------------
# Original question: Does Frankin usually sit in one position on the chair?
# Refined question: Does Frankin usually sit in one position on the chair?
# Original answer: No.
# Refined answer: No.
# ----------------------------------------------------------------------------------------------------
# Original question: Where does Frankin usually keep his wallet?
# Refined question: Where does Frankin usually keep his wallet?
# Original answer: In his right back pocket.
# Refined answer: In his right back pocket.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: When did the vlogger feel hospitality?
# Refined question: When did the vlogger experience hospitality?
# Original answer: During his communication with the fruit vendor from Afghanistan.
# Refined answer: During his interaction with the fruit vendor from Afghanistan.
# ----------------------------------------------------------------------------------------------------
# Original question: What is Magic J's job?
# Refined question: What is Magic J's profession?
# Original answer: DJ.
# Refined answer: DJ.
# ----------------------------------------------------------------------------------------------------
# Original question: What is the right way to live safely in Tottenham?
# Refined question: What is the best way to live safely in Tottenham?
# Original answer: Just mind your own business.
# Refined answer: Just mind your own business.
# ----------------------------------------------------------------------------------------------------
# Original question: What can effectively reduce the crime rate in Tottenham?
# Refined question: What can effectively reduce the crime rate in Tottenham?
# Original answer: Installing cameras everywhere.
# Refined answer: Installing cameras everywhere.
# ----------------------------------------------------------------------------------------------------
# Original question: Where do homeless live in Tottenham?
# Refined question: Where do the homeless live in Tottenham?
# Original answer: In tents or abandoned cars.
# Refined answer: In tents or abandoned cars.
# ----------------------------------------------------------------------------------------------------
# Original question: Which are Magic J's favorite restaurants in Tottenham?
# Refined question: Which are Magic J's favorite restaurants in Tottenham?
# Original answer: Tottenham Town Bakery and Chick King.
# Refined answer: Tottenham Town Bakery and Chick King.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: What is the favorite element used by this Internet celebrity brand “Miss Jophiel”？
# Refined question: What is the favorite element used by the Internet celebrity brand 'Miss Jophiel'?
# Original answer: Flowers.
# Refined answer: Flowers.
# ----------------------------------------------------------------------------------------------------
# Original question: Which country does Mia live in?
# Refined question: Which country does Mia live in?
# Original answer: Canada.
# Refined answer: Canada.
# ----------------------------------------------------------------------------------------------------
# Original question: Can people buy brand new clothes at Threadup?
# Refined question: Can people buy brand new clothes at Threadup?
# Original answer: No.
# Refined answer: No.
# ----------------------------------------------------------------------------------------------------
# Original question: How many skirts did Mia review?
# Refined question: How many skirts did Mia review?
# Original answer: Five.
# Refined answer: Five.
# ----------------------------------------------------------------------------------------------------
# Original question: Is Mia married?
# Refined question: Is Mia married?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: What brand is the pink bra in the video?
# Refined question: What brand is the pink bra in the video?
# Original answer: GYMSHARK.
# Refined answer: GYMSHARK.
# ----------------------------------------------------------------------------------------------------
# Original question: What is the blogger allergic to?
# Refined question: What is the blogger allergic to?
# Original answer: Dust.
# Refined answer: Dust.
# ----------------------------------------------------------------------------------------------------
# Original question: Where are people most likely to see TALA?
# Refined question: Where are people most likely to see TALA?
# Original answer: Tik Tok.
# Refined answer: TikTok.
# ----------------------------------------------------------------------------------------------------
# Original question: Does the blogger prefer to wear tight pants or loose pants when going to the gym?
# Refined question: Does the blogger prefer to wear tight pants or loose pants when going to the gym?
# Original answer: Tight pants.
# Refined answer: Tight pants.
# ----------------------------------------------------------------------------------------------------
# Original question: Does Vanquish have any dedicated fitness clothing?
# Refined question: Does Vanquish have any dedicated fitness clothing?
# Original answer: No.
# Refined answer: No.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Original question: How many Lululemon leggings did Keltie review?
# Refined question: How many Lululemon leggings did Keltie review?
# Original answer: Two.
# Refined answer: Two.
# ----------------------------------------------------------------------------------------------------
# Original question: If you are a person who sweats easily, is it recommended to buy 437 leggings?
# Refined question: If you sweat easily, is it recommended to buy 437 leggings?
# Original answer: Not recommended.
# Refined answer: It is not recommended.
# ----------------------------------------------------------------------------------------------------
# Original question: If you want to show off your buttocks, which brand of leggings should you buy?
# Refined question: If you want to show off your buttocks, which brand of leggings should you buy?
# Original answer: Alphaletes.
# Refined answer: Alphaletes.
# ----------------------------------------------------------------------------------------------------
# Original question: Which country does Keltie live in?
# Refined question: Which country does Keltie live in?
# Original answer: Canada.
# Refined answer: Canada.
# ----------------------------------------------------------------------------------------------------
# Original question: Is Keltie slim?
# Refined question: Is Keltie slim?
# Original answer: Yes.
# Refined answer: Yes.
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================

# %%
import json
import os

small_test = []
samples_per_file = 50
with open("data/annotations/CZ_1_refined.json", "r") as f:
    CZ = json.load(f)
with open("data/annotations/ZZ_1_refined.json", "r") as f:
    ZZ = json.load(f)

count = 0
for video in CZ:
    if not video["video_url"].startswith("https://www.youtube.com/watch?v="):
        continue
    if os.path.exists(video["path"]):
        small_test.append(video)
        count += 1
        if count >= samples_per_file:
            break

count = 0
for video in ZZ:
    if not video["video_url"].startswith("https://www.youtube.com/watch?v="):
        continue
    if os.path.exists(video["path"]):
        small_test.append(video)
        count += 1
        if count >= samples_per_file:
            break

with open("data/annotations/small_test.json", "w") as f:
    json.dump(small_test, f, indent=4, ensure_ascii=False)

# %%
import json

data_list = [
    "data/annotations/CZ_1_refined.json",
    "data/annotations/CZ_2_refined.json",
    "data/annotations/CZ_3_refined.json",
    "data/annotations/ZZ_1_refined.json",
    "data/annotations/ZZ_2_refined.json",
    "data/annotations/ZZ_3_refined.json",
    "data/annotations/ZZ_4_refined.json",
]
test_set = json.load(open("data/annotations/small_test.json", "r"))
test_id = [video["video_id"] for video in test_set]
small_training_set = []
for data in data_list:
    with open(data, "r") as f:
        data = json.load(f)
    for video in data:
        if video["video_id"] not in test_id:
            small_training_set.append(video)

print(len(test_id))
print(len(small_training_set))
with open("data/annotations/small_train.json", "w") as f:
    json.dump(small_training_set, f)

# %%
import json
from utils.general import *

processing_config = json.load(open("configs/processing_config.json"))
save_dir = os.path.join(processing_config["save_dir"])
clip_dir = processing_config["input_dir"]


def add_paths(data):
    with open(data, "r") as f:
        videos = json.load(f)
    for video in videos:
        video_id = video["path"].split("/")[-1].split(".")[0]
        marker = video["video_id"][:4]
        save_path = os.path.join(
            save_dir, marker, generate_file_name(video["path"]) + ".pkl"
        )
        clip_path = os.path.join(
            clip_dir, marker, video_id
        )
        if os.path.exists(save_path):
            video["mem_path"] = save_path
        else:
            video["mem_path"] = ""
        if os.path.exists(clip_path):
            video["clip_path"] = clip_path
        else:
            video["clip_path"] = ""
    with open(data, "w") as f:
        json.dump(videos, f, indent=4, ensure_ascii=False)


add_paths("data/annotations/small_test.json")
add_paths("data/annotations/small_train.json")

# %%
import json


def convert_to_jsonl(data):
    with open(data, "r") as f:
        videos = json.load(f)
    qas = []
    for video in videos:
        for qa in video["qa_list"]:
            qas.append(
                {
                    "video_id": video["video_id"],
                    "video_url": video["video_url"],
                    "video_path": video["path"],
                    "clip_path": video["clip_path"],
                    "mem_path": video["mem_path"],
                    "question": qa["question"],
                    "answer": qa["answer"],
                }
            )
    with open(f"data/annotations/{data.split('/')[-1].split('.')[0]}.jsonl", "w") as f:
        for qa in qas:
            f.write(json.dumps(qa) + "\n")


convert_to_jsonl("data/annotations/small_test.json")
convert_to_jsonl("data/annotations/small_train.json")

# %%
def check_if_contains_mem(data):
    count = 0
    with open(data, "r") as f:
        videos = json.load(f)
    for video in videos:
        if video["mem_path"]:
            count += 1
    return count


print(check_if_contains_mem("data/annotations/small_train.json"))
print(check_if_contains_mem("data/annotations/small_test.json"))
# Out:
# 526
# 100
